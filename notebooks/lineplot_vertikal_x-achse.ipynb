# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
data = pd.read_csv("aufmasse_freigabe_datum_anzahl.csv", sep=",")

data
# Out:
#     freigabe_datum  count(1)
# 0       2020-01-02         1
# 1       2020-01-08         2
# 2       2020-01-09         6
# 3       2020-01-10        11
# 4       2020-01-13         9
# ..             ...       ...
# 459     2021-10-22        12
# 460     2021-10-26        11
# 461     2021-10-27         9
# 462     2021-10-28         3
# 463     2021-10-29         7
#
# [464 rows x 2 columns]

# %%
# Filter Labels, so nicht lesbar bei vielen Werten

labels = data["freigabe_datum"].copy()

size = len(labels)
for i in range(0,size):
    if i % 4 != 0:
        labels[i] = ""

labels
# Out:
# 0      2020-01-02
# 1
# 2
# 3
# 4      2020-01-13
#           ...
# 459
# 460    2021-10-26
# 461
# 462
# 463
# Name: freigabe_datum, Length: 464, dtype: object

# %%
sn.set(font_scale=1.0)
fig, ax = plt.subplots(figsize=(30,10), dpi=100)
ax.set_xticks(range(len(labels)))
ax.set_xticklabels(labels, rotation=50)
sn.lineplot(x="freigabe_datum", y="count(1)", data=data, ax=ax)
# Out:
# <AxesSubplot:xlabel='freigabe_datum', ylabel='count(1)'>
